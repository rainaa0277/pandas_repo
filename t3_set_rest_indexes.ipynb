# %%
import pandas as pd

# %%
person = {"first": ["Rishab", "Rajas", "Sam"],
          "last": ["Raina", "Raut", "Sulek"],
          "email": ["rainaa0277@gmail.com", "rajasraut@yahoo.com", "samsulek01@gmail.com"]}

# %%
person_df = pd.DataFrame(person)
person_df
# Out:
#     first   last                 email
# 0  Rishab  Raina  rainaa0277@gmail.com
# 1   Rajas   Raut   rajasraut@yahoo.com
# 2     Sam  Sulek  samsulek01@gmail.com

# %%
#right now index is 0,1,2 and lets change emal to the index
person_df.set_index("email",inplace=True)

# %%
person_df
# Out:
#                        first   last
# email
# rainaa0277@gmail.com  Rishab  Raina
# rajasraut@yahoo.com    Rajas   Raut
# samsulek01@gmail.com     Sam  Sulek

# %%
person_df.loc['rainaa0277@gmail.com','last']
# Out:
# 'Raina'

# %%
person_df.loc[['rainaa0277@gmail.com','samsulek01@gmail.com'],['first','last']]
# Out:
#                        first   last
# email
# rainaa0277@gmail.com  Rishab  Raina
# samsulek01@gmail.com     Sam  Sulek

# %%
person_df.iloc[0:2,[0,1]]
# Out:
#                        first   last
# email
# rainaa0277@gmail.com  Rishab  Raina
# rajasraut@yahoo.com    Rajas   Raut

# %% [markdown]
# ## Coming back to stack-overflow dataset

# %%
#Load the datasets
df = pd.read_csv('data\survey_results_public.csv',index_col='Respondent')
schema_df = pd.read_csv('data\survey_results_schema.csv',index_col='Column')

# %%
#By default we can only see 20columns, let's change that to 85 so we can see all the columns
pd.set_option('display.max_columns',85)

#Similarly, we can change the maximum number of rows displayed
pd.set_option('display.max_rows',85)

# %%
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df.sort_index(inplace=True) #default=ascending

# %%
schema_df.index
# Out:
# Index(['Age', 'Age1stCode', 'BetterLife', 'BlockchainIs', 'BlockchainOrg',
#        'CareerSat', 'CodeRev', 'CodeRevHrs', 'CompFreq', 'CompTotal',
#        'Containers', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'Dependents', 'DevEnviron', 'DevType', 'EdLevel', 'EduOther',
#        'Employment', 'EntTeams', 'Ethnicity', 'Extraversion', 'FizzBuzz',
#        'Gender', 'Hobbyist', 'ITperson', 'ImpSyn', 'JobFactors', 'JobSat',
#        'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'LastHireDate', 'LastInt', 'MainBranch', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'MiscTechDesireNextYear', 'MiscTechWorkedWith', 'OffOn',
#        'OpSys', 'OpenSource', 'OpenSourcer', 'OrgSize',
#        'PlatformDesireNextYear', 'PlatformWorkedWith', 'PurchaseHow',
#        'PurchaseWhat', 'Respondent', 'ResumeUpdate', 'SOAccount', 'SOComm',
# ...

# %%
schema_df.head(3)
# Out:
#                                                  QuestionText
# Column
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...
# BetterLife  Do you think people born today will have a bet...

# %%
schema_df.loc["FizzBuzz","QuestionText"]
# Out:
# 'Have you ever been asked to solve FizzBuzz in an interview?'
